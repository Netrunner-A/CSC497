# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm

# %%
import splitfolders

# %%
actions = ['leftshoot', 'left',
          'shoot', 'rightshoot', 'right']
action_label = {actions:i for i, actions in enumerate(actions)}
IMAGE_SIZE = (200, 150)

# %%
input_folder = "C:/Users/ammaR/Desktop/CSC496 Project/gameProject/PythonApplication1/images"

output_folder = "C:/Users/ammaR/Desktop/CSC496 Project/gameProject/PythonApplication1/dataset"

model_path = "C:/Users/ammaR/Desktop/CSC496 Project/gameProject/PythonApplication1/model"

# %%
array1 = np.load("C:/Users/ammaR/Desktop/CSC496 Project/gameProject/PythonApplication1/file1.txt.npy")
plt.imshow(array1)

# %%
plt.imshow(train_images[0])

# %%
splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 1465 files [00:06, 218.49 files/s]

# %%
def load_dataset():
    
    datasets = [output_folder+"/train", output_folder+"/test"]
    output = []
    
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        for folder in os.listdir(dataset):
            label = action_label[folder]
            
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                images.append(cv2.resize(cv2.cvtColor(cv2.imread(os.path.join(dataset, folder, file)),cv2.COLOR_BGR2RGB), IMAGE_SIZE) )
                labels.append(label)
        images = np.array(images)
        labels = np.array(labels)
        
        output.append((images, labels))
        
    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_dataset()
# Out:
# Loading C:/Users/ammaR/Desktop/CSC496 Project/gameProject/PythonApplication1/dataset/train
# 100%|███████████████████████████████████████████████████████████████████████████████| 472/472 [00:04<00:00, 116.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 79.58it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 481/481 [00:05<00:00, 82.27it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 82.07it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 180/180 [00:02<00:00, 82.89it/s]
# Loading C:/Users/ammaR/Desktop/CSC496 Project/gameProject/PythonApplication1/dataset/test
# 100%|██████████████████████████████████████████████████████████████████████████████████| 59/59 [00:00<00:00, 84.15it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 83.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [00:00<00:00, 84.47it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 71.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 82.72it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
def display_random_image(actions, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + actions[labels[index]])
    plt.show()

# %%
display_random_image(actions, train_images, train_labels)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 200, 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
action_label
# Out:
# {'leftshoot': 0, 'left': 1, 'shoot': 2, 'rightshoot': 3, 'right': 4}

# %%
array = np.reshape(cv2.resize(cv2.cvtColor(cv2.imread(output_folder+"/train/left/screenshot4880.jpg"),cv2.COLOR_BGR2RGB), IMAGE_SIZE), [1,150,200,3])

array.shape
# Out:
# (1, 150, 200, 3)

# %%
train_images.shape
# Out:
# (1160, 150, 200, 3)

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=20, validation_split = 0.2)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 10s 1s/step - loss: 1.7023 - accuracy: 0.4149 - val_loss: 1.2084 - val_accuracy: 0.4224
# Epoch 2/20
# 8/8 [==============================] - 8s 1s/step - loss: 1.1823 - accuracy: 0.4526 - val_loss: 1.1684 - val_accuracy: 0.4440
# Epoch 3/20
# 8/8 [==============================] - 9s 1s/step - loss: 1.0612 - accuracy: 0.5614 - val_loss: 1.0811 - val_accuracy: 0.4655
# Epoch 4/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.9778 - accuracy: 0.6110 - val_loss: 1.0633 - val_accuracy: 0.5129
# Epoch 5/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.8935 - accuracy: 0.6379 - val_loss: 1.0154 - val_accuracy: 0.5388
# Epoch 6/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.7919 - accuracy: 0.6907 - val_loss: 0.9644 - val_accuracy: 0.5776
# Epoch 7/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.6761 - accuracy: 0.7457 - val_loss: 0.9158 - val_accuracy: 0.5862
# Epoch 8/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.5596 - accuracy: 0.8114 - val_loss: 0.8804 - val_accuracy: 0.6207
# Epoch 9/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.4367 - accuracy: 0.8459 - val_loss: 0.8982 - val_accuracy: 0.6034
# Epoch 10/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.3360 - accuracy: 0.8879 - val_loss: 0.9983 - val_accuracy: 0.6034
# Epoch 11/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.2602 - accuracy: 0.9138 - val_loss: 0.9942 - val_accuracy: 0.6422
# Epoch 12/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.1910 - accuracy: 0.9494 - val_loss: 1.0847 - val_accuracy: 0.6207
# Epoch 13/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.1419 - accuracy: 0.9688 - val_loss: 1.2122 - val_accuracy: 0.6379
# Epoch 14/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.1068 - accuracy: 0.9698 - val_loss: 1.2023 - val_accuracy: 0.6724
# Epoch 15/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.0975 - accuracy: 0.9752 - val_loss: 1.2422 - val_accuracy: 0.6422
# Epoch 16/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.1088 - accuracy: 0.9698 - val_loss: 1.4258 - val_accuracy: 0.6207
# Epoch 17/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.0976 - accuracy: 0.9688 - val_loss: 1.2516 - val_accuracy: 0.6336
# Epoch 18/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.0759 - accuracy: 0.9763 - val_loss: 1.3482 - val_accuracy: 0.6552
# Epoch 19/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.0482 - accuracy: 0.9892 - val_loss: 1.4590 - val_accuracy: 0.6250
# Epoch 20/20
# 8/8 [==============================] - 9s 1s/step - loss: 0.0389 - accuracy: 0.9871 - val_loss: 1.6651 - val_accuracy: 0.6250

# %%
model.save(model_path)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/ammaR/Desktop/CSC496 Project/gameProject/PythonApplication1/model\assets
# INFO:tensorflow:Assets written to: C:/Users/ammaR/Desktop/CSC496 Project/gameProject/PythonApplication1/model\assets

# %%
pred = model.predict(test_images)
# Out:
# 5/5 [==============================] - 0s 50ms/step

# %%
pred_labels = np.argmax(pred, axis=1)

# %%
display_random_image(actions, test_images, pred_labels)

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=actions, 
           yticklabels=actions, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input

model = VGG16(weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
train_features = model.predict(train_images)
test_features = model.predict(test_images)
# Out:
# 37/37 [==============================] - 36s 968ms/step
# 5/5 [==============================] - 5s 918ms/step

# %%
n_train, x, y, z = train_features.shape
n_test, x, y, z = test_features.shape
numFeatures = x * y * z

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components = 2)

X = train_features.reshape((n_train, x*y*z))
pca.fit(X)

C = pca.transform(X)
C1 = C[:,0]
C2 = C[:,1]

# %%
plt.subplots(figsize=(10,10))

for i, class_name in enumerate(actions):
    plt.scatter(C1[train_labels == i][:1000], C2[train_labels == i][:1000], label = class_name, alpha=0.4)
plt.legend()
plt.title("PCA Projection")
plt.show()
